# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("/content/drive/MyDrive/데이터강의/project_3차/3.라벨링/df_v4.csv")
df1.drop(['Unnamed: 0'], axis=1, inplace=True)
df1
# Out:
#        No                                         CARPAL  \
# 0       1      ['0.424167', '0.76', '0.468333', '0.325']
# 1       2     ['0.419167', '0.675', '0.441667', '0.255']
# 2       3        ['0.520833', '0.665', '0.385', '0.245']
# 3       4      ['0.455', '0.72375', '0.396667', '0.275']
# 4       5      ['0.5025', '0.675', '0.421667', '0.2275']
# ...   ...                                            ...
# 1223  661        ['0.483333', '0.74875', '0.37', '0.23']
# 1224  662      ['0.495833', '0.77', '0.398333', '0.245']
# 1225  663       ['0.4425', '0.73', '0.368333', '0.2425']
# 1226  664      ['0.518333', '0.70125', '0.34', '0.2025']
# 1227  665  ['0.5125', '0.748125', '0.351667', '0.22125']
#
#                                                  TMCP  \
# 0            ['0.769167', '0.5175', '0.115', '0.095']
# 1            ['0.75', '0.51125', '0.0966667', '0.07']
# 2         ['0.761667', '0.474375', '0.09', '0.06625']
# 3           ['0.745833', '0.53625', '0.095', '0.075']
# ...

# %%
for i in range(len(df1)):
  if df1['gender'][i]==0:
    df1['img_path'][i] = f'/content/drive/MyDrive/Colab Notebooks/3차프로젝트/2.전처리/Male/{df1["No"][i]}_M.jpg'
  elif df1['gender'][i]==1:
    df1['img_path'][i] = f'/content/drive/MyDrive/Colab Notebooks/3차프로젝트/2.전처리/Female/{df1["No"][i]}_F.jpg'
# Out:
# <ipython-input-26-386d8027df7f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['img_path'][i] = f'/content/drive/MyDrive/Colab Notebooks/3차프로젝트/2.전처리/Female/{df1["No"][i]}_F.jpg'
# <ipython-input-26-386d8027df7f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['img_path'][i] = f'/content/drive/MyDrive/Colab Notebooks/3차프로젝트/2.전처리/Male/{df1["No"][i]}_M.jpg'

# %%
df1.to_csv('/content/drive/MyDrive/Colab Notebooks/3차프로젝트/df_BA.csv',index=False)
